# %%
# %matplotlib inline
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import statistics as stat
# Load in csv
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
# Set x-axis and tick locations.
x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]
# Plot the data.
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)")
plt.xticks(tick_locations, pyber_ride_df["Month"])
plt.show()

# %%
pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)")
plt.show()

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.show()

# %%
# 1. Add error bars
stdev = pyber_ride_df["Avg. Fare ($USD)"]

pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)", yerr=stdev)
plt.show()
# Out:
# C:\Users\Carlos\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# C:\Users\Carlos\anaconda3\envs\PythonData\lib\site-packages\numpy\core\_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)

# %%
# 1. Add error bars
stdev = statistics.stdev(pyber_ride_df["Avg. Fare ($USD)"])

pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)", yerr=stdev)
plt.show()

#help(stdev) gives crazy stats on data frame no need to do it here.

# %%
#2. Add caps to the error bars
pyber_ride_df.plot.bar(x="Month", y="Avg. Fare ($USD)", yerr=stdev, capsize=3)
plt.show()

# %%
# 3. Change the color of the bars to sky blue
pyber_ride_df.plot.bar(x="Month", 
                       y="Avg. Fare ($USD)", 
                       yerr=stdev, 
                       capsize=3, 
                       color="#75bbfd")
plt.show()

# %%
#4. Rotate the labels on the x-axis to horizontal
pyber_ride_df.plot.bar(x="Month", 
                       y="Avg. Fare ($USD)", 
                       yerr=stdev, 
                       capsize=3, 
                       color="#75bbfd")

plt.xticks(rotation=0)

plt.show()

# %%
#5. Set the y-axis increment to every $5
pyber_ride_df.plot.bar(x="Month", 
                       y="Avg. Fare ($USD)", 
                       yerr=stdev, 
                       capsize=3, 
                       color="#75bbfd")

plt.xticks(rotation=0)

plt.yticks(np.arange(0, 55, step=5.0))

plt.show()
